# %%
 from cox import store

# %%
# s = store.Store('../outdir/', '04fca56b-e66d-441c-b473-c82b39b8948c')
s = store.Store('../outdir/', 'c6da92cf-c5f4-4835-8a7e-ec9dcf457e9d')
s = store.Store('/home/hasalman/azure-madry/wd_1e-4/adversarial_training_stepLR/', 'resnet50_batch512')

s.tables
# Out:
# {'ckpts': <cox.store.Table at 0x7fda5b34ab90>,
#  'logs': <cox.store.Table at 0x7fda5b76ae90>}

# %%
s['logs'].df
# Out:
#     epoch  nat_prec1  adv_prec1  nat_loss  adv_loss  train_prec1  train_loss  \
# 0       1  15.613999       -1.0  4.407103      -1.0     6.013892    5.611731
# 1       2  27.983999       -1.0  3.464998      -1.0    23.179335    3.836681
# 2       3  38.374001       -1.0  2.803594      -1.0    33.869198    3.138354
# 3       4  43.118000       -1.0  2.532718      -1.0    39.935619    2.783750
# 4       5  42.913998       -1.0  2.586819      -1.0    43.507599    2.580164
# ..    ...        ...        ...       ...       ...          ...         ...
# 85     86  75.848000       -1.0  0.963963      -1.0    78.478416    0.879691
# 86     87  75.785995       -1.0  0.964525      -1.0    78.601097    0.876856
# 87     88  75.795998       -1.0  0.966764      -1.0    78.658272    0.873410
# 88     89  75.722000       -1.0  0.968629      -1.0    78.672760    0.872188
# 89     90  75.801994       -1.0  0.966402      -1.0    78.720566    0.869742
#
#              time
# 0     1308.284095
# ...

# %%
s['metadata'].df
# Out:
#                                               params
# 0  gAN9cQAoWAsAAABjb25maWdfcGF0aHEBTlgJAAAAZXZhbF...
